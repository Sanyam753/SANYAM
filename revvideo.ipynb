# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanyam753/SANYAM/blob/main/revvideo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

video_path = '/content/horse.mp4'  # Replace with the path to your video file
output_path = '/content/output.mp4'  # Replace with the desired output path

cap = cv2.VideoCapture(video_path)
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Define the codec for the output video file
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

while(cap.isOpened()):
    ret, frame = cap.read()

    if not ret:
        break

    cv2_imshow(frame)
    out.write(frame)  # Write the frame to the video file

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()  # Release the video writer object
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=640x352>
# <PIL.Image.Image image mode=RGB size=640x352>
# <PIL.Image.Image image mode=RGB size=640x352>
# <PIL.Image.Image image mode=RGB size=640x352>
# <PIL.Image.Image image mode=RGB size=640x352>
# <PIL.Image.Image image mode=RGB size=640x352>
# <PIL.Image.Image image mode=RGB size=640x352>
# <PIL.Image.Image image mode=RGB size=640x352>
# <PIL.Image.Image image mode=RGB size=640x352>
# <PIL.Image.Image image mode=RGB size=640x352>
# <PIL.Image.Image image mode=RGB size=640x352>
# <PIL.Image.Image image mode=RGB size=640x352>
# <PIL.Image.Image image mode=RGB size=640x352>
# <PIL.Image.Image image mode=RGB size=640x352>
